# %% [markdown]
# <a href="https://colab.research.google.com/github/mrtrench99-coder/mrtrench99-coder/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Pandas:",pd.__version__)
print("Numpy:",pd.__version__)
print("Matplotlib:",pd.__version__)
# Out:
# Pandas: 2.2.2
# Numpy: 2.2.2
# Matplotlib: 2.2.2

# %%
df=pd.read_csv("netflix_titles.csv")
df=pd.read_csv("netflix_titles.csv",index_col=0)
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
df.shape
df.info()
df.isnull().sum()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8807 entries, s1 to s8807
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      6173 non-null   object
#  3   cast          7982 non-null   object
#  4   country       7976 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8803 non-null   object
#  8   duration      8804 non-null   object
#  9   listed_in     8807 non-null   object
#  10  description   8807 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 825.7+ KB
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df['director']=df["director"].fillna('Unknown')
df["cast"]=df["cast"].fillna('Unknown')
df['country']=df["country"].fillna('Unknown')
df['rating']=df["rating"].fillna('Unknown')
df['duration']=df["duration"].fillna('Unknown')
df["date_added"] = pd.to_datetime(df["date_added"], errors="coerce")
df.isnull().sum()
# Out:
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      98
# release_year     0
# rating           0
# duration         0
# listed_in        0
# description      0
# dtype: int64

# %%
df[df['date_added'].isnull()][['title','date_added']].head(10)
# Out:
#                                                title date_added
# show_id
# s6067    A Young Doctor's Notebook and Other Stories        NaT
# s6080                                Abnormal Summit        NaT
# s6175                Anthony Bourdain: Parts Unknown        NaT
# s6178                                       忍者ハットリくん        NaT
# s6214                                  Bad Education        NaT
# s6280                    Being Mary Jane: The Series        NaT
# s6305                       Big Dreams, Small Spaces        NaT
# s6319                                         Bitten        NaT
# s6358                                   Bondi Rescue        NaT
# s6362                                     Borderline        NaT

# %%
df=df.dropna(subset="date_added")
df.isnull().sum()
# Out:
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
df["year_added"]=df["date_added"].dt.year
df["month_added"]=df["date_added"].dt.month   #.dt access date time properties
df.head()
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          Unknown
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          Unknown
# s5       TV Show           Kota Factory          Unknown
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# s4                                                 Unknown        Unknown
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#         date_added  release_year rating   duration  \
# show_id
# s1      2021-09-25          2020  PG-13     90 min
# ...

# %%
df[["date_added","month_added","year_added"]].head()
# Out:
#         date_added  month_added  year_added
# show_id
# s1      2021-09-25            9        2021
# s2      2021-09-24            9        2021
# s3      2021-09-24            9        2021
# s4      2021-09-24            9        2021
# s5      2021-09-24            9        2021

# %%
df.head(-10)
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water          Unknown
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans          Unknown
# s5       TV Show           Kota Factory          Unknown
# ...          ...                    ...              ...
# s8793      Movie            Young Tiger           Mu Chu
# s8794      Movie   Yours, Mine and Ours     Raja Gosnell
# s8795      Movie                 اشتباك     Mohamed Diab
# s8796    TV Show        Yu-Gi-Oh! Arc-V          Unknown
# s8797    TV Show             Yunus Emre          Unknown
#
#                                                       cast        country  \
# show_id
# s1                                                 Unknown  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
counts=df["type"].value_counts()
print(counts)
ratio=counts["Movie"]/counts["TV Show"]
np.round(ratio,1)
# Out:
# type
# Movie      6131
# TV Show    2578
# Name: count, dtype: int64
# np.float64(2.4)

# %% [markdown]
# It appears in fact that netflix has more movies than series. The number is almost 2.4 times the number of series.

# %%
movie_trends=df[df["type"]=="Movie"]["year_added"].value_counts().sort_index()
series_trends=df[df["type"]=="TV Show"]["year_added"].value_counts().sort_index()


yearly_total=df["year_added"].value_counts().sort_index()
yearly_total

import matplotlib.pyplot as plt

plt.figure()
plt.plot(yearly_total.index,yearly_total.values)
plt.title("Total Netflix Content Added Per Year")
plt.xlabel("Year")
plt.ylabel("Number of titles being added")
plt.show()

# %% [markdown]
# There's no abrupt increase in the rise of movies from 2008 - 2014. The increase in the rate of content being added started from 2015 and rose high upto 2019 (around 125 movies to 2000) 2000 movies were added in 2019 which was the peak and later it dropped but still higher than the starting years

# %%
movie_trends=df[df["type"]=="Movie"]["year_added"].value_counts().sort_index()
series_trends=df[df["type"]=="TV Show"]["year_added"].value_counts().sort_index()

plt.figure()
plt.plot(movie_trends.index,movie_trends.values)
plt.plot(series_trends.index,series_trends.values)
plt.title("Movies Vs Series Trends")
plt.xlabel("Year")
plt.ylabel("Number of Titles Added")
plt.legend(["Movies","TV Shows"])
plt.show()

# %% [markdown]
# `*Graph Overview*`
# Netflix started its production with movies.During the early years only movies were added .Around 2010 , series were added too because Netflix created an habit to their customers to watch and spend time in their website. So people were habituated with longer duration series too. There wasn't any abrupt increase in both of the graphs upto 2015. From 2015 we can see the increase in the graph meaning the movies and series are being added heavily upto 2019. But still the rate of movies being added is much higher than the rate of series being added. Movies peak was in 2019 , where around 2000 movies were added in a single year whereas the peak of Series was in 2020, where 600 series were added. It's obvious beacuse series takes long production times to make and build and they r long commitment movies basicallly and obv the profit is huge too but longer period of duration to build and provide when compared to the movies. After this covid started,so much movies and series were not being made but if we had to compare the duraion or watch time of people in these years, It will be high.
#
# ***Conclusion***
# As the interest of people towards watching movies and series rose , the number of titles being added increased too .A Company or Business is successfull when they understand and listen to the needs of their customers and Netflix has done a great job in that aspect, no wonder a successfull company and increase in the rate of movies and series being added.
# Peak for movies was in 2019 and for Series was in 2020 and it later dropped but still higher than the beginning years

# %%
df["listed_in"]
# Out:
# show_id
# s1                                           Documentaries
# s2         International TV Shows, TV Dramas, TV Mysteries
# s3       Crime TV Shows, International TV Shows, TV Act...
# s4                                  Docuseries, Reality TV
# s5       International TV Shows, Romantic TV Shows, TV ...
#                                ...
# s8803                       Cult Movies, Dramas, Thrillers
# s8804               Kids' TV, Korean TV Shows, TV Comedies
# s8805                              Comedies, Horror Movies
# s8806                   Children & Family Movies, Comedies
# s8807       Dramas, International Movies, Music & Musicals
# Name: listed_in, Length: 8709, dtype: object

# %%
df["listed_in"] = df["listed_in"].astype(str)
df["listed_in"] = df["listed_in"].str.split(", ")
df_exploded=df.explode("listed_in")
df_exploded["listed_in"].value_counts().head(10)
# Out:
# listed_in
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1328
# Documentaries                869
# Action & Adventure           859
# Independent Movies           756
# TV Dramas                    739
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
df_exploded.groupby(["type", "listed_in"]).size().sort_values(ascending=False).head(10)
# Out:
# type     listed_in
# Movie    International Movies        2752
#          Dramas                      2427
#          Comedies                    1674
# TV Show  International TV Shows      1328
# Movie    Documentaries                869
#          Action & Adventure           859
#          Independent Movies           756
# TV Show  TV Dramas                    739
# Movie    Children & Family Movies     641
#          Romantic Movies              616
# dtype: int64

# %%
top_genres=df_exploded["listed_in"].value_counts().head(10)
top_genres.plot(kind='pie')
plt.title("Top Netflix Genres")
plt.xlabel("Genres")
plt.ylabel("Count")
plt.show()

# %%
top_genres=df_exploded["listed_in"].value_counts().head(10)
top_genres.plot(kind='bar')
plt.title("Top Netflix Genres")
plt.xlabel("Genres")
plt.ylabel("Count")
plt.show()

# %%
df["country"]=df["country"].fillna("Unknown")
df["country"]=df["country"].str.split(",")
df_country=df.explode("country")
df_country["country"].value_counts().head(10)
# Out:
# country
# United States     3169
# India             1007
# Unknown            827
# United Kingdom     611
#  United States     474
# Canada             259
# Japan              255
# France             209
# South Korea        206
#  France            180
# Name: count, dtype: int64

# %%
top_countries=df_country["country"].value_counts().head(10)
top_countries.plot(kind="bar")
plt.title("Top 10 Content Producing Countries")
plt.xlabel("Countries")
plt.ylabel("Count")
plt.show()

# %%
df_country.groupby(["country","type"]).size().sort_values(ascending=False).head(10)
# Out:
# country         type
# United States   Movie      2364
# India           Movie       927
# United States   TV Show     805
# Unknown         Movie       440
#  United States  Movie       388
# Unknown         TV Show     387
# United Kingdom  Movie       382
#                 TV Show     229
# Canada          Movie       187
# Japan           TV Show     170
# dtype: int64
